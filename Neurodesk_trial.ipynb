# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmedkanyiri/Microstructure2025-M/blob/main/Neurodesk_trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.environ["LD_PRELOAD"] = "";
os.environ["APPTAINER_BINDPATH"] = "/content"
os.environ["MPLCONFIGDIR"] = "/content/matplotlib-mpldir"
os.environ["LMOD_CMD"] = "/usr/share/lmod/lmod/libexec/lmod"

# !curl -J -O https://raw.githubusercontent.com/neurodesk/neurocommand/main/googlecolab_setup.sh
# !chmod +x googlecolab_setup.sh
# !./googlecolab_setup.sh

os.environ["MODULEPATH"] = ':'.join(map(str, list(map(lambda x: os.path.join(os.path.abspath('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/'), x),os.listdir('/cvmfs/neurodesk.ardc.edu.au/neurodesk-modules/')))))

# %%
import lmod
await lmod.avail()

# %%
# %%shell
# cp -r /content/drive/MyDrive/raw /content/raw
# zip -r raw.zip raw

# %%
os.environ["PROJECT_ROOT"] = "/content/test"
os.environ["ORIG_DATA"] = "/content/raw.zip"
os.environ["GOOGLE_COLAB"] = "True"

# %%
await lmod.load('fsl/6.0.4')
await lmod.load('mriqc/24.0.2')
await lmod.load('bidscoin/4.6.2')

# %%
# !rm -rf /content/test /content/Microstructure2025-M/
# !git clone https://github.com/ahmedkanyiri/Microstructure2025-M.git

# %%
# !cd $HOME && pwd
# !ls

# %%
# %%shell
# !bash Microstructure2025-M/data_structure_and_validation.sh

# %%
# %%shell
# raw_dir="${PROJECT_ROOT}/raw"
# deriv_dir="${PROJECT_ROOT}/derivatives"
#
# echo "$raw_dir"
# echo "$deriv_dir"
#
#
# Microstructure2025-M/Mriqc.sh "$raw_dir" "$deriv_dir"

# %%
# %%shell
# raw_dir="${PROJECT_ROOT}/raw"
# deriv_dir="${PROJECT_ROOT}/derivatives"
#
# echo "$raw_dir"
# echo "$deriv_dir"
#
#
# Microstructure2025-M/Preprocessing.sh "$raw_dir" "$deriv_dir"
